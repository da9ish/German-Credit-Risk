# %% [markdown]
# # Task
#
# * The aim here is to classify whether a loan application is good or bad. \n
# * A loan application is judged good or bad based on certain features.
#
# # Dataset description
#
# The dataset was collected by Prof. Hofmann.
# It contains 1000 samples with 21 features. They are as follows
# * Status of existing checking account
# * Duration in month
# * Credit history
# * Purpose
# * Credit amount
# * Savings account/bonds
# * Present employment since
# * Installment rate in percentage of disposable income
# * Personal status and sex
# * Other debtors / guarantors
# * Present residence since
# * Property
# * Age in years
# * Other installment plans
# * Housing
# * Number of existing credits at this bank
# * Job
# * Number of people being liable to provide maintenance for \n,
# * Telephone
# * Foreign worker
#
# * The problem at hand involves classification. We are using Confusion Matrix to evaluate the performance of our model.
# * The Confusion Matrix gives us a measure of True Positive, True Negative, False Positive & False Negative.
# * The sum of False Positive & False Negative should be minimum. Identifying bad loan application as good is worse then classifying good application as bad.
#
# # Literature Survey
#
# [RBloggers](https://www.r-bloggers.com/classification-on-the-german-credit-database/), have built different models and used AUC for the classification task on the German Credit Scoring Dataset.\n,
#
# | Model     | Metric       | Score |
# | ------------- |:-------------:| -----:|
# | LogisticRegression    | AUC | 0.7340997 |
# | RandomForest      | AUC      |    0.7609792|
#
# [Some students at Penn University](https://onlinecourses.science.psu.edu/stat857/node/220/), have built different models and used Accuracy Score.
#
# | Model     | Metric       | Score |
# | ------------- |:-------------:| -----:|
# | LogisticRegression    | AUC | 64% |
# | RandomForest      | Accuracy Score      |73.4%|

# %% [markdown]
# # Pipeline
#
# ### Data Collection
# - Data was collected from csv and formatted accordingly
#
# ### EDA
# - Checking the distribution and count of the features
#
# ### Splitting
# - Splitting the data into train, val, test sets
#
# ### EDA
# 1. Checking the distribution of the data after splitting
# 2. Analysis of the data
#     - Univariate
#         1. QQ Plot
#         2. Box Whisker Plot
#         3. 7-point Summary
#     - Bivariate
#         1. Facet Plot
#     - Multivariate
#         1. Pair Plot
#         2. Heatmap
#
# ### Feature Preprocessing
# 1. Missing Value Interpretaion
# 2. Outlier Treatment
#     - Visualization
#     - Transformation
#     - Removal
#
# ### Encoding
# 1. Label Encoding
# 2. One Hot Encoding
#
# ### Modelling
# 1. Logistic Regression
# 2. SVM
# 3. Decision Tree
#
# ### Accuracy
#
# #### With no transformation
# - <strong>Logistic Regression</strong>
#     - Accuracy on Validation Set: 0.75625
#     - Accuracy on Test Set: 0.73
#
# - <strong>SVM</strong>
#     - Accuracy on Validation Set: 0.74375
#     - Confusion matrix for Validation Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 119       | 1         |
# | 2    | 40        | 0         |
#
#     - Accuracy on Test Set: 0.705
#     - Confusion matrix for Test Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 141       | 0         |
# | 2    | 58        | 0         |
#
# - <strong>Decision Tree</strong>
#     - Accuracy on Validation Set: 0.69375
#     - Confusion matrix for Validation Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 90        | 30        |
# | 2    | 19        | 21        |
#
#     - Accuracy on Test Set: 0.675
#     - Confusion matrix for Test Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 108       | 33        |
# | 2    | 32        | 27        |
#
# #### With partial transformation
# - <strong>Logistic Regression</strong>
#     - Accuracy on Validation Set: 0.7875
#     - Accuracy on Test Set: 0.73
#
# - <strong>SVM</strong> <br>
#     - Accuracy on Validation Set: 0.75625
#     - Confusion matrix for Validation Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 119       | 1         |
# | 2    | 38        | 2         |
#
#     - Accuracy on Test Set: 0.72
#     - Confusion matrix for Test Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 135       | 6         |
# | 2    | 50        | 9         |
#
# - <strong>Decision Tree</strong>
#     - Accuracy on Validation Set: 0.71875
#     - Confusion matrix for Validation Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 93        | 27        |
# | 2    | 18        | 22        |
#
#     - Accuracy on Test Set: 0.7
#     - Confusion matrix for Test Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 110       | 31        |
# | 2    | 29        | 30        |
#
#
# #### With full transformation
# - <strong>Logistic Regression</strong>
#     - Accuracy on Validation Set: 0.7625
#     - Accuracy on Test Set: 0.72
#
# - <strong>SVM</strong>
#     - Accuracy on Validation Set: 0.81875
#     - Confusion matrix for Validation Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 117       | 13        |
# | 2    | 26        | 14        |
#
#     - Accuracy on Test Set: 0.73
#     - Confusion matrix for Test Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 135       | 6         |
# | 2    | 48        | 11        |
#
# - <strong>Decision Tree</strong>
#     - Accuracy on Validation Set: 0.7
#     - Confusion matrix for Validation Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 91        | 29        |
# | 2    | 19        | 21        |
#
#     - Accuracy on Test Set: 0.69
#     - Confusion matrix for Test Set
#
# |      | Predicted | Predicted |
# |------|-----------|-----------|
# | True | 1         | 2         |
# | 1    | 109       | 32        |
# | 2    | 30        | 29        |
#
# ## Top Features
# - Amount
# - Credit History
# - Checking Ac
# - Age
# - Duration

# %% [markdown]
# # Imports

# %% [markdown]
# Packages and Libraries for processing data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import preprocessing
from sklearn import svm, tree
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer
# %matplotlib inline

pd.options.display.max_columns = 999
sns.set_palette(sns.cubehelix_palette(1))
sns.set_style('darkgrid')

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 6
fig_size[1] = 4
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# # Important Functions

# %%
def get_data():
    columns = ["checking_ac", "duration", "credit_history", "purpose", "amount", "saving_ac",
           "employment_status", "installment_rate", 'personal_status_sex', "debtor_guarantor", "residence_since",
          "property", "age", "installment_plan", "housing", "existing_credits", "job", "liable_count", "telephone",
          "foreign_worker", "target"]
    df = pd.read_csv("../../data/german.data2.csv", delimiter=' ', index_col=False, names=columns)
    return df
    
def get_cols(df, num_cols):
    cat_cols = list(set(df.columns.values) - set(num_cols))
    for col in cat_cols:
        df[col] = df[col].astype('category')
    for col in num_cols:
        df[col] = df[col].astype('float')
    return df, cat_cols

def dist_plot(df, col_name):
    plt.title(i)
    sns.distplot(df[col_name])
    plt.show()
    
def count_plot(df, col_name):
    plt.title(col_name)
    sns.set_palette(sns.cubehelix_palette(1))
    s = df[col_name].value_counts()
    ax = s.plot.bar(width=.8) 
    for i, v in s.reset_index().iterrows():
        ax.text(i, v[col_name] + 0.2 , v[col_name], color='red')
    
    plt.show()


def qq_plot(df, col_name):
    stats.probplot(df[col_name], dist="norm", plot=plt)
    plt.title(col_name)
    plt.show()
    
def box_plot(df, col_name):
    sns.boxplot(df[col_name])
    plt.title(col_name)
    plt.show()
    
def facet_plot(df, row, col, over):
    sns.set_palette(sns.color_palette('coolwarm'))
    g = sns.FacetGrid(df, col=col, row=row)
    plt.title(row)
    g_map = g.map(plt.hist, over)
    
def pair_plot(df):
    sns.set_palette(sns.cubehelix_palette(1))
    sns.pairplot(df)
    
def heatmap(df):
    sns.set_palette(sns.cubehelix_palette(1))
    sns.heatmap(df.corr())
    
def left_skew_removal(df, col_name):
    df[col_name] = np.sqrt(df[col_name])
    return df[col_name]

def right_skew_removal(df, col_name):
    df[col_name] = np.log(df[col_name])
    return df[col_name]

def remove_outlier(df, col_name):
#     print(col_name)
    q75, q25 = np.percentile(df[col_name], [75 ,25])
    iqr = q75 - q25
    min_v = q25 - (iqr*1.5)
    max_v = q75 + (iqr*1.5)

    for indx, val in df[col_name].iteritems():
        if val < min_v:
            df[col_name][indx] = min_v
        elif val > max_v:
            df[col_name][indx] = max_v
            
    plt.subplot('211')
    dist_plot(df, col_name)
    plt.subplot('212')
    box_plot(df, col_name)
    plt.show()
    
def plot_features(X_train, X_test, y_train, y_test, model):
    accuracies = []
    features = []
    plt.figure(figsize=(15,15))
    for idx, feature in enumerate(X_train.columns):
        model = model
        model.fit(pd.DataFrame(X_train[feature]), y_train.values.ravel())
        y_pred = model.predict(pd.DataFrame(X_test[feature]))
        acc = accuracy_score(y_pred=y_pred, y_true=y_test)
        accuracies.append(acc)
        features.append(feature)

    features = [x for x in sorted(zip(accuracies,features))]
    accuracies = sorted(accuracies)
    plt.title('Feature Importances')
    plt.barh(range(len(accuracies)), accuracies, color='b', align='center')
    plt.yticks(range(len(features)), features)
    plt.xlabel('Relative Importance')
    plt.show()
    
def plot_features_clf(clf):
    features = X_train.columns
    importances = clf.feature_importances_
    indices = np.argsort(importances)

    fig_size = plt.rcParams["figure.figsize"]
    fig_size[0] = 9
    fig_size[1] = 12
    plt.rcParams["figure.figsize"] = fig_size
    plt.title('Feature Importances')
    plt.barh(range(len(indices)), importances[indices], color='b', align='center')
    plt.yticks(range(len(indices)), features[indices])
    plt.xlabel('Relative Importance')
    plt.show()

# %% [markdown]
# # Loading Data

# %% [markdown]
# Retrieving data from csv, adding columns, changing the datatype of categorial columns and loading it into pandas dataframe. Seperating the numerical and categorial columns for EDA

# %%
df = get_data()

# %% [markdown]
# Making the data readable

# %%
cat_dict = {
    "A11": "-0",
    "A12": "0-200",
    "A13": "200+",
    "A14": "no checking acc",
    "A30": "no credit",
    "A31": "all paid duly",
    "A32": "existing paid duly",
    "A33": "payment delay",
    "A34": "critical acc",
    "A40": "car (new)",
    "A41": "car (old)",
    "A42": "furniture/equipment",
    "A43": "radio/television",
    "A44": "domestic appliances",
    "A45": "repairs",
    "A46": "education",
    "A47": "vacation",
    "A48": "retraining",
    "A49": "business",
    "A410": "others",
    "A61": "-100",
    "A62": "100-500",
    "A63": "500-1000",
    "A64": "1000+",
    "A65": "no acc",
    "A71": "unemployed",
    "A72": "-1",
    "A73": "1-4",
    "A74": "4-7",
    "A75": "7+",
    "A91": "male-div/sep",
    "A92": "male-single",
    "A93": "male-married",
    "A94": "female-div/sep/mar",
    "A95": "female-single",
    "A101": "none",
    "A102": "co-applicant",
    "A103": "guarantor",
    "A121": "real est",
    "A122": "building",
    "A123": "car",
    "A124": "none",
    "A141": "bank",
    "A142": "store",
    "A143": "none",
    "A151": "rent",
    "A152": "own",
    "A153": "free",
    "A171": "unempl-no res",
    "A172": "unempl-res",
    "A173": "empl",
    "A174": "high empl",
    "A191": "yes",
    "A191": "no",
    "A201": "yes",
    "A202": "no"}

df.replace(cat_dict, inplace=True)
df.target.replace({2: 0}, inplace=True)

# %%
df.nunique()
# Out:
# checking_ac              4
# duration                33
# credit_history           5
# purpose                 10
# amount                 921
# saving_ac                5
# employment_status        5
# installment_rate         4
# personal_status_sex      4
# debtor_guarantor         3
# residence_since          4
# property                 4
# age                     53
# installment_plan         3
# housing                  3
# existing_credits         4
# job                      4
# liable_count             2
# telephone                2
# foreign_worker           2
# target                   2
# dtype: int64

# %% [markdown]
# The Series above shows the number of unique values of all the features. All the features except `amount`, `age`, and `duration` look like categorical variables.

# %%
num_cols = ["duration", "amount", "age"]

df, cat_cols = get_cols(df, num_cols)

# %% [markdown]
# ## Count Plot

# %% [markdown]
# Count plot for all categorial features

# %%
plt.subplot(121)
for col in cat_cols:
    count_plot(df, col)

# %%
for i in cat_cols:
    count_plot(df, i)
#     print("Value \t Count")
#     print(df[i].value_counts())
    sns.factorplot(x='target', col=i, kind='count', data=df)
    plt.show()
    print(df.groupby([i, 'target']).target.count())
# Out:
# Value 	 Count
# 1-4           339
# 7+            253
# 4-7           174
# -1            172
# unemployed     62
# Name: employment_status, dtype: int64
# employment_status  target
# -1                 0          70
#                    1         102
# 1-4                0         104
#                    1         235
# 4-7                0          39
#                    1         135
# 7+                 0          64
#                    1         189
# unemployed         0          23
#                    1          39
# Name: target, dtype: int64
# Value 	 Count
# none     814
# bank     139
# store     47
# Name: installment_plan, dtype: int64
# installment_plan  target
# bank              0          57
#                   1          82
# none              0         224
#                   1         590
# store             0          19
#                   1          28
# Name: target, dtype: int64
# Value 	 Count
# radio/television       280
# car (new)              234
# furniture/equipment    181
# car (old)              103
# business                97
# education               50
# repairs                 22
# domestic appliances     12
# others                  12
# retraining               9
# Name: purpose, dtype: int64
# purpose              target
# business             0          34
#                      1          63
# car (new)            0          89
#                      1         145
# car (old)            0          17
#                      1          86
# domestic appliances  0           4
#                      1           8
# education            0          22
#                      1          28
# furniture/equipment  0          58
#                      1         123
# others               0           5
#                      1           7
# radio/television     0          62
#                      1         218
# repairs              0           8
#                      1          14
# retraining           0           1
#                      1           8
# Name: target, dtype: int64
# Value 	 Count
# 1    700
# 0    300
# Name: target, dtype: int64
# target  target
# 0       0         300
# 1       1         700
# Name: target, dtype: int64
# Value 	 Count
# male-married          548
# male-single           310
# female-div/sep/mar     92
# male-div/sep           50
# Name: personal_status_sex, dtype: int64
# personal_status_sex  target
# female-div/sep/mar   0          25
#                      1          67
# male-div/sep         0          20
#                      1          30
# male-married         0         146
#                      1         402
# male-single          0         109
#                      1         201
# Name: target, dtype: int64
# Value 	 Count
# none            907
# guarantor        52
# co-applicant     41
# Name: debtor_guarantor, dtype: int64
# debtor_guarantor  target
# co-applicant      0          18
#                   1          23
# guarantor         0          10
#                   1          42
# none              0         272
#                   1         635
# Name: target, dtype: int64
# Value 	 Count
# no      596
# A192    404
# Name: telephone, dtype: int64
# telephone  target
# A192       0         113
#            1         291
# no         0         187
#            1         409
# Name: target, dtype: int64
# Value 	 Count
# yes    963
# no      37
# Name: foreign_worker, dtype: int64
# foreign_worker  target
# no              0           4
#                 1          33
# yes             0         296
#                 1         667
# Name: target, dtype: int64
# Value 	 Count
# car         332
# real est    282
# building    232
# none        154
# Name: property, dtype: int64
# property  target
# building  0          71
#           1         161
# car       0         102
#           1         230
# none      0          67
#           1          87
# real est  0          60
#           1         222
# Name: target, dtype: int64
# Value 	 Count
# existing paid duly    530
# critical acc          293
# payment delay          88
# all paid duly          49
# no credit              40
# Name: credit_history, dtype: int64
# credit_history      target
# all paid duly       0          28
#                     1          21
# critical acc        0          50
#                     1         243
# existing paid duly  0         169
#                     1         361
# no credit           0          25
#                     1          15
# payment delay       0          28
#                     1          60
# Name: target, dtype: int64
# Value 	 Count
# own     713
# rent    179
# free    108
# Name: housing, dtype: int64
# housing  target
# free     0          44
#          1          64
# own      0         186
#          1         527
# rent     0          70
#          1         109
# Name: target, dtype: int64
# Value 	 Count
# empl             630
# unempl-res       200
# high empl        148
# unempl-no res     22
# Name: job, dtype: int64
# job            target
# empl           0         186
#                1         444
# high empl      0          51
#                1          97
# unempl-no res  0           7
#                1          15
# unempl-res     0          56
#                1         144
# Name: target, dtype: int64
# Value 	 Count
# -100        603
# no acc      183
# 100-500     103
# 500-1000     63
# 1000+        48
# Name: saving_ac, dtype: int64
# saving_ac  target
# -100       0         217
#            1         386
# 100-500    0          34
#            1          69
# 1000+      0           6
#            1          42
# 500-1000   0          11
#            1          52
# no acc     0          32
#            1         151
# Name: target, dtype: int64
# Value 	 Count
# no checking acc    394
# -0                 274
# 0-200              269
# 200+                63
# Name: checking_ac, dtype: int64
# checking_ac      target
# -0               0         135
#                  1         139
# 0-200            0         105
#                  1         164
# 200+             0          14
#                  1          49
# no checking acc  0          46
#                  1         348
# Name: target, dtype: int64

# %%
def plot_hist(df, i):
    sns.set_palette(sns.color_palette('coolwarm'))
    plt.title(i)
    b = int(1+(3.322*np.log(df[i].shape[0])))
    sns.distplot(df[i], bins=b)
    plt.show()
    plt.title("Target vs " + i)
    df.groupby('target')[i].hist(alpha=0.85, bins=b)
    plt.legend([i, 'Good Loans'])
    plt.show()

# %%
plot_hist(df, 'amount')

# %% [markdown]
# * The feature Amount is bimodal and right skewed
# * The light blue shade in the 2nd figure shows good loans in respective bins.
# * As Amount decreases, proportion of good loans keep decreasing.

# %%
plot_hist(df, 'age')

# %% [markdown]
# * Age is multimodal.
# * Applicants with age more than 25 are associated with higher rates of default.

# %%
dist_plot(df, 'duration')

# %% [markdown]
# Multimodal and right-skewed.

# %% [markdown]
# # Splitting

# %% [markdown]
# Splitting the data into train val test set (64%, 16%, 20%)

# %%
df = get_data()
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, :-1], df.iloc[:, 20:21], test_size=0.2, random_state=3)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=3)

# %% [markdown]
# Shapes of the sets

# %%
print("X Train: " + str(X_train.shape))
print("Y Train: " + str(y_train.shape))

print("X Test: " + str(X_test.shape))
print("Y Test: " + str(y_test.shape))

print("X Val: " + str(X_val.shape))
print("Y Val: " + str(y_val.shape))
# Out:
# X Train: (640, 20)
# Y Train: (640, 1)
# X Test: (200, 20)
# Y Test: (200, 1)
# X Val: (160, 20)
# Y Val: (160, 1)

# %%
X_train, cat_cols_X_train = get_cols(X_train, num_cols)

# %% [markdown]
# ## Distribution Plot

# %% [markdown]
# Distribution after splitting

# %%
def plot_qq(col):
    sns.set_palette(sns.color_palette('coolwarm'))
    q1 = X_train[col].quantile(np.arange(0.0, 1.0, 0.1))
    q2 = X_val[col].quantile(np.arange(0.0, 1.0, 0.1))
    plt.title(col)
    plt.plot(q1, q1, color='b')
    plt.plot(q1, q2)
    plt.legend(['Train Data', 'Test Data'])
    plt.show()

# %%
plot_qq('amount')

# %%
plot_qq('duration')

# %%
plot_qq('age')

# %%
for i in num_cols_x_train:
    sns.set_palette(sns.color_palette('coolwarm'))
    q75, q25 = np.percentile(X_train[i], [75 ,25])
    iqr = q75 - q25
    min_v = q25 - (iqr*1.5)
    max_v = q75 + (iqr*1.5)
    print("Outliers Count")
    print(X_train[min_v > X_train[i]][i].count() + X_train[max_v < X_train[i]][i].count())
    print("Indx \t Value")
    print(X_train[min_v > X_train[i]][i].sort_values())
    print(X_train[max_v < X_train[i]][i].sort_values())

    plt.title(i)
    plt.axvline(x=min_v)
    plt.axvline(x=max_v)
    ax = sns.boxplot(X_train[i])
    plt.show()
# Out:
# Outliers Count
# 46
# Indx 	 Value
# Series([], Name: duration, dtype: int64)
# 35     45
# 832    45
# 998    45
# 285    47
# 927    48
# 36     48
# 522    48
# 1      48
# 622    48
# 295    48
# 814    48
# 467    48
# 130    48
# 945    48
# 310    48
# 11     48
# 788    48
# 549    48
# 829    48
# 887    48
# 44     48
# 273    48
# 568    48
# 787    48
# 191    48
# 650    48
# 538    48
# 444    48
# 657    48
# 115    48
# 552    48
# 569    48
# 375    48
# 915    48
# 921    48
# 242    48
# 286    48
# 78     54
# 616    60
# 332    60
# 672    60
# 374    60
# 373    60
# 134    60
# 714    60
# 677    72
# Name: duration, dtype: int64
# Outliers Count
# 49
# Indx 	 Value
# Series([], Name: amount, dtype: int64)
# 889     7824
# 113     7855
# 525     7966
# 645     7980
# 17      8072
# 653     8086
# 70      8133
# 983     8229
# 491     8318
# 828     8335
# 945     8358
# 980     8386
# 417     8471
# 130     8487
# 509     8588
# 402     8648
# 549     8858
# 268     8978
# 616     9157
# 808     9283
# 291     9398
# 78      9436
# 57      9566
# 812     9629
# 684     9857
# 295     9960
# 134    10144
# 657    10222
# 927    10297
# 672    10366
# 902    10477
# 205    10623
# 285    10722
# 953    10974
# 736    11560
# 395    11760
# 832    11816
# 274    11998
# 921    12749
# 381    12976
# 373    13756
# 714    14027
# 744    14179
# 378    14318
# 236    14555
# 374    14782
# 917    14896
# 887    15672
# 915    18424
# Name: amount, dtype: int64
# Outliers Count
# 0
# Indx 	 Value
# Series([], Name: installment_rate, dtype: int64)
# Series([], Name: installment_rate, dtype: int64)
# Outliers Count
# 0
# Indx 	 Value
# Series([], Name: residence_since, dtype: int64)
# Series([], Name: residence_since, dtype: int64)
# Outliers Count
# 15
# Indx 	 Value
# Series([], Name: age, dtype: int64)
# 438    65
# 624    65
# 137    66
# 75     66
# 774    66
# 723    66
# 554    67
# 0      67
# 846    68
# 917    68
# 163    70
# 186    74
# 756    74
# 430    74
# 330    75
# Name: age, dtype: int64
# Outliers Count
# 2
# Indx 	 Value
# Series([], Name: existing_credits, dtype: int64)
# 653    4
# 590    4
# Name: existing_credits, dtype: int64
# Outliers Count
# 94
# Indx 	 Value
# Series([], Name: liable_count, dtype: int64)
# 160    2
# 551    2
# 983    2
# 814    2
# 716    2
# 830    2
# 516    2
# 467    2
# 21     2
# 704    2
# 886    2
# 889    2
# 234    2
# 110    2
# 465    2
# 674    2
# 265    2
# 210    2
# 581    2
# 941    2
# 415    2
# 827    2
# 4      2
# 275    2
# 501    2
# 72     2
# 969    2
# 78     2
# 503    2
# 978    2
#       ..
# 837    2
# 413    2
# 479    2
# 302    2
# 923    2
# 990    2
# 88     2
# 617    2
# 871    2
# 611    2
# 863    2
# 527    2
# 327    2
# 205    2
# 170    2
# 329    2
# 242    2
# 191    2
# 392    2
# 404    2
# 422    2
# 933    2
# 609    2
# 349    2
# 666    2
# 971    2
# 184    2
# 756    2
# 460    2
# 204    2
# Name: liable_count, Length: 94, dtype: int64

# %% [markdown]
# ### 7-point Summary

# %%
X_train.describe()
# Out:
#          duration        amount  installment_rate  residence_since  \
# count  640.000000    640.000000        640.000000       640.000000
# mean    20.714063   3258.750000          2.929688         2.823437
# std     12.202047   2759.704832          1.142326         1.102741
# min      4.000000    250.000000          1.000000         1.000000
# 25%     12.000000   1385.000000          2.000000         2.000000
# 50%     18.000000   2356.500000          3.000000         3.000000
# 75%     24.000000   3960.500000          4.000000         4.000000
# max     72.000000  18424.000000          4.000000         4.000000
#
#               age  existing_credits  liable_count
# count  640.000000        640.000000    640.000000
# mean    35.389063          1.400000      1.146875
# std     11.398880          0.567233      0.354258
# min     19.000000          1.000000      1.000000
# 25%     27.000000          1.000000      1.000000
# 50%     33.000000          1.000000      1.000000
# 75%     42.000000          2.000000      1.000000
# max     75.000000          4.000000      2.000000

# %% [markdown]
# ### Standard Deviation

# %%
std_dev = X_train.std(axis=0)
print(std_dev)
# Out:
# duration      12.202047
# amount      2759.704832
# age           11.398880
# dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Facet Plot

# %%
# for j in num_cols_x_train:
for i in cat_cols_x_train:
    facet_plot(df, i, 'target', 'amount')

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Pair Plot

# %%
sns.set_palette(sns.cubehelix_palette(1))
sns.pairplot(df, hue='target');
plt.show()

# %% [markdown]
# ## Heatmap

# %%
heatmap(X_train)

# %% [markdown]
# # Feature Preprocessing

# %% [markdown]
# ## Missing Value Interpretation

# %% [markdown]
# Check for missing values

# %%
missing_val = X_train.isnull().sum()
print(missing_val)
# Out:
# checking_ac            0
# duration               0
# credit_history         0
# purpose                0
# amount                 0
# saving_ac              0
# employment_status      0
# installment_rate       0
# personal_status_sex    0
# debtor_guarantor       0
# residence_since        0
# property               0
# age                    0
# installment_plan       0
# housing                0
# existing_credits       0
# job                    0
# liable_count           0
# telephone              0
# foreign_worker         0
# dtype: int64

# %% [markdown]
# # Encoding

# %% [markdown]
# Encoding numeric and categorical values

# %% [markdown]
# ## Label Encoding

# %%
x_col = {'checking_ac': checking_ac, 'saving_ac': saving_ac, 'employment_status': employment_status, 'job': job, 'telephone': telephone, 'foreign_worker': foreign_worker}
for indx, val in x_col.items():
    col = indx
    rep_dict = val
    X_train[col].replace(rep_dict, inplace=True)
    X_val[col].replace(rep_dict, inplace=True)
    X_test[col].replace(rep_dict, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-b97cdeef5854> in <module>()
# ----> 1 x_col = {'checking_ac': checking_ac, 'saving_ac': saving_ac, 'employment_status': employment_status, 'job': job, 'telephone': telephone, 'foreign_worker': foreign_worker}
#       2 for indx, val in x_col.items():
#       3     col = indx
#       4     rep_dict = val
#       5     X_train[col].replace(rep_dict, inplace=True)
#
# NameError: name 'checking_ac' is not defined

# %%
X_val.head()
# Out:
#      checking_ac  duration credit_history purpose  amount  saving_ac  \
# 656            2        12            A32     A40     888          0
# 187            2        16            A34     A40    1175          0
# 770            0        24            A32     A41    2812          5
# 288            2        12            A32     A43    1092          0
# 106            1        18            A31     A40    6458          0
#
#      employment_status  installment_rate personal_status_sex debtor_guarantor  \
# 656                  4                 4                 A93             A101
# 187                  0                 2                 A93             A101
# 770                  4                 2                 A92             A101
# 288                  2                 4                 A92             A103
# 106                  4                 2                 A93             A101
#
#      residence_since property  age installment_plan housing  existing_credits  \
# 656                4     A123   41             A141    A152                 1
# 187                3     A123   68             A143    A153                 3
# 770                4     A121   26             A143    A151                 1
# 288                4     A121   49             A143    A152                 2
# 106                4     A124   39             A141    A152                 2
#
#      job  liable_count  telephone  foreign_worker
# 656    1             2          0               0
# 187    0             1          1               0
# 770    2             1          0               0
# 288    2             1          1               0
# 106    3             2          1               0

# %% [markdown]
# ## One Hot Encoding

# %%
def one_hot_encoding(train, val, test, col_name):
    x = pd.get_dummies(train[col_name])
    y = pd.get_dummies(test[col_name])
    z = pd.get_dummies(val[col_name])
    for i in x.columns:
        train[col_name + ' is ' + i + '?'] = x[i]
        
    for i in z.columns:
        val[col_name + ' is ' + i + '?'] = z[i]
        
    for i in y.columns:
        test[col_name + ' is ' + i + '?'] = y[i]

    train.drop(col_name, axis=1, inplace=True)
    val.drop(col_name, axis=1, inplace=True)
    test.drop(col_name, axis=1, inplace=True)

# %%
for i in one_hot_encoding_cols:
    one_hot_encoding(X_train, X_val, X_test, i)

# %%
pd.get_dummies(X_train, drop_first=True)
# Out:
#      duration   amount   age  checking_ac_A12  checking_ac_A13  \
# 719      20.0   6148.0  31.0                1                0
# 284      24.0   3878.0  37.0                1                0
# 169      24.0   1935.0  31.0                1                0
# 160      24.0   2872.0  36.0                0                0
# 279      24.0   1901.0  29.0                0                0
# 986      42.0   6289.0  33.0                0                1
# 553      12.0   1995.0  27.0                1                0
# 612      21.0   3357.0  29.0                0                0
# 302      24.0   1344.0  37.0                0                1
# 479      15.0   1478.0  44.0                0                0
# 413      10.0   1597.0  40.0                0                0
# 834      15.0   2327.0  25.0                0                1
# 876      18.0   1940.0  36.0                0                0
# 837       4.0    601.0  23.0                0                0
# 123      10.0    781.0  63.0                0                1
# 768      12.0   3617.0  28.0                1                0
# 356      12.0   2331.0  49.0                0                0
# 122      12.0   1768.0  24.0                0                0
# 198      24.0   2760.0  36.0                1                0
# 714      60.0  14027.0  27.0                1                0
# 115                   0                   0                   0         0
# 96                    0                   0                   0         0
# 178                   1                   0                   0         0
# 965                   0                   0                   0         0
# ..                  ...                 ...                 ...       ...
# 488                   0                   0                   0         1
# 510                   0                   0                   0         0
# 865                   0                   0                   0         0
# 850                   1                   0                   0         0
# 975                   0                   0                   0         1
# 297                   0                   0                   0         1
# 828                   0                   0                   0         0
# 501                   0                   0                   0         0
# 908                   1                   0                   0         1
# 679                   0                   0                   0         0
# 990                   1                   0                   0         1
# 840                   0                   0                   0         0
# 231                   0                   0                   0         1
# 710                   1                   0                   0         0
# 23                    0                   0                   0         0
# 832                   1                   0                   0         0
# 936                   0                   0                   0         1
# 35                    1                   0                   0         1
# 369                   0                   0                   0         0
# 636                   0                   0                   0         0
# 229                   0                   0                   0         0
# 62                    0                   0                   0         0
# 688                   0                   0                   0         0
# 843                   0                   0                   0         0
# 173                   0                   0                   0         0
# 875                   1                   0                   0         0
# 70                    0                   0                   0         0
# 252                   0                   0                   0         0
# 204                   1                   0                   0         1
# 120                   1                   0                   0         0
#
#      job_A173  job_A174  liable_count_2  telephone_A192  foreign_worker_A202
# 719         1         0               0               1                    0
# 284         1         0               0               1                    0
# 169         1         0               0               1                    0
# 160         1         0               1               1                    0
# 279         0         1               0               1                    0
# 986         1         0               0               0                    0
# 553         1         0               0               0                    0
# 612         1         0               0               0                    0
# 302         0         0               1               0                    0
# 479         1         0               1               1                    0
# 413         0         0               1               0                    1
# 834         0         0               0               0                    0
# 876         0         1               0               1                    0
# 837         0         0               1               0                    0
# 123         1         0               0               1                    0
# 768         1         0               0               1                    0
# 356         1         0               0               1                    0
# 122         0         0               0               0                    0
# 198         1         0               0               1                    0
# 714         0         1               0               1                    0
# 306         0         0               0               0                    0
# 152         1         0               0               0                    0
# 792         1         0               0               0                    0
# 183         1         0               0               1                    0
# 507         0         1               1               1                    0
# 248         1         0               0               0                    0
# 115         1         0               0               1                    0
# 96          1         0               0               0                    0
# 178         0         1               1               1                    0
# 965         1         0               0               0                    0
# ..        ...       ...             ...             ...                  ...
# 488         0         0               0               0                    1
# 510         1         0               0               0                    0
# 865         1         0               0               0                    0
# 850         1         0               0               0                    1
# 975         0         0               0               0                    0
# 297         0         0               0               0                    1
# 828         1         0               0               0                    0
# 501         1         0               1               0                    0
# 908         0         0               0               0                    0
# 679         1         0               0               0                    0
# 990         0         0               1               0                    0
# 840         1         0               0               0                    0
# 231         0         0               0               0                    0
# 710         0         1               0               1                    0
# 23          1         0               0               0                    0
# 832         1         0               0               0                    0
# 936         0         0               0               0                    0
# 35          0         0               0               0                    0
# 369         1         0               0               0                    0
# 636         1         0               0               0                    0
# 229         1         0               0               0                    0
# 62          0         1               0               1                    0
# 688         1         0               0               1                    0
# 843         1         0               0               1                    0
# 173         1         0               0               0                    1
# 875         1         0               0               0                    0
# 70          1         0               0               0                    0
# 252         1         0               0               0                    0
# 204         0         0               1               0                    0
# 120         1         0               0               1                    0
#
# [640 rows x 54 columns]

# %%
X_test.head()
# Out:
#      checking_ac  duration  amount  saving_ac  employment_status  \
# 642            1        15    4623          2                  2
# 762            0        12    2214          0                  2
# 909            2         9    3195          5                  2
# 199            2        18    4297          0                  4
# 586            0         9    2799          0                  2
#
#      installment_rate  residence_since  age  existing_credits  job  \
# 642                 3                2   40                 1    3
# 762                 4                3   24                 1    1
# 909                 1                2   33                 1    1
# 199                 4                3   40                 1    3
# 586                 2                2   36                 2    2
#
#      liable_count  telephone  foreign_worker  installment_plan is A141?  \
# 642             1          1               0                          0
# 762             1          0               0                          0
# 909             1          0               0                          0
# 199             1          1               0                          0
# 586             2          0               0                          0
#
#      installment_plan is A142?  installment_plan is A143?  \
# 642                          0                          1
# 762                          0                          1
# 909                          0                          1
# 199                          0                          1
# 586                          0                          1
#
#      personal_status_sex is A91?  personal_status_sex is A92?  \
# 642                            0                            0
# 762                            0                            0
# 909                            0                            1
# 199                            1                            0
# 586                            0                            0
#
#      personal_status_sex is A93?  personal_status_sex is A94?  \
# 642                            1                            0
# 762                            1                            0
# 909                            0                            0
# 199                            0                            0
# 586                            1                            0
#
#      property is A121?  property is A122?  property is A123?  \
# 642                  0                  1                  0
# 762                  0                  1                  0
# 909                  1                  0                  0
# 199                  0                  0                  0
# 586                  1                  0                  0
#
#      property is A124?  credit_history is A30?  credit_history is A31?  \
# 642                  0                       0                       0
# 762                  0                       0                       0
# 909                  0                       0                       0
# 199                  1                       0                       0
# 586                  0                       0                       0
#
#      credit_history is A32?  credit_history is A33?  credit_history is A34?  \
# 642                       1                       0                       0
# 762                       1                       0                       0
# 909                       1                       0                       0
# 199                       0                       1                       0
# 586                       0                       0                       1
#
#      housing is A151?  housing is A152?  housing is A153?  \
# 642                 0                 1                 0
# 762                 0                 1                 0
# 909                 0                 1                 0
# 199                 0                 1                 0
# 586                 1                 0                 0
#
#      debtor_guarantor is A101?  debtor_guarantor is A102?  \
# 642                          1                          0
# 762                          1                          0
# 909                          1                          0
# 199                          1                          0
# 586                          1                          0
#
#      debtor_guarantor is A103?  purpose is A40?  purpose is A41?  \
# 642                          0                0                0
# 762                          0                0                0
# 909                          0                1                0
# 199                          0                0                0
# 586                          0                1                0
#
#      purpose is A410?  purpose is A42?  purpose is A43?  purpose is A44?  \
# 642                 0                0                0                0
# 762                 0                0                1                0
# 909                 0                0                0                0
# 199                 0                1                0                0
# 586                 0                0                0                0
#
#      purpose is A45?  purpose is A46?  purpose is A48?  purpose is A49?
# 642                0                1                0                0
# 762                0                0                0                0
# 909                0                0                0                0
# 199                0                0                0                0
# 586                0                0                0                0

# %% [markdown]
# ## Normalizing the data

# %%
norm_X_train = preprocessing.normalize(X_train)
norm_X_test = preprocessing.normalize(X_test)

# %%
X_val.head()
# Out:
#      checking_ac  duration  amount  saving_ac  employment_status  \
# 656            2        12     888          0                  4
# 187            2        16    1175          0                  0
# 770            0        24    2812          5                  4
# 288            2        12    1092          0                  2
# 106            1        18    6458          0                  4
#
#      installment_rate  residence_since  age  existing_credits  job  \
# 656                 4                4   41                 1    1
# 187                 2                3   68                 3    0
# 770                 2                4   26                 1    2
# 288                 4                4   49                 2    2
# 106                 2                4   39                 2    3
#
#      liable_count  telephone  foreign_worker  installment_plan is A141?  \
# 656             2          0               0                          1
# 187             1          1               0                          0
# 770             1          0               0                          0
# 288             1          1               0                          0
# 106             2          1               0                          1
#
#      installment_plan is A142?  installment_plan is A143?  \
# 656                          0                          0
# 187                          0                          1
# 770                          0                          1
# 288                          0                          1
# 106                          0                          0
#
#      personal_status_sex is A91?  personal_status_sex is A92?  \
# 656                            0                            0
# 187                            0                            0
# 770                            0                            1
# 288                            0                            1
# 106                            0                            0
#
#      personal_status_sex is A93?  personal_status_sex is A94?  \
# 656                            1                            0
# 187                            1                            0
# 770                            0                            0
# 288                            0                            0
# 106                            1                            0
#
#      property is A121?  property is A122?  property is A123?  \
# 656                  0                  0                  1
# 187                  0                  0                  1
# 770                  1                  0                  0
# 288                  1                  0                  0
# 106                  0                  0                  0
#
#      property is A124?  credit_history is A30?  credit_history is A31?  \
# 656                  0                       0                       0
# 187                  0                       0                       0
# 770                  0                       0                       0
# 288                  0                       0                       0
# 106                  1                       0                       1
#
#      credit_history is A32?  credit_history is A33?  credit_history is A34?  \
# 656                       1                       0                       0
# 187                       0                       0                       1
# 770                       1                       0                       0
# 288                       1                       0                       0
# 106                       0                       0                       0
#
#      housing is A151?  housing is A152?  housing is A153?  \
# 656                 0                 1                 0
# 187                 0                 0                 1
# 770                 1                 0                 0
# 288                 0                 1                 0
# 106                 0                 1                 0
#
#      debtor_guarantor is A101?  debtor_guarantor is A102?  \
# 656                          1                          0
# 187                          1                          0
# 770                          1                          0
# 288                          0                          0
# 106                          1                          0
#
#      debtor_guarantor is A103?  purpose is A40?  purpose is A41?  \
# 656                          0                1                0
# 187                          0                1                0
# 770                          0                0                1
# 288                          1                0                0
# 106                          0                1                0
#
#      purpose is A410?  purpose is A42?  purpose is A43?  purpose is A44?  \
# 656                 0                0                0                0
# 187                 0                0                0                0
# 770                 0                0                0                0
# 288                 0                0                1                0
# 106                 0                0                0                0
#
#      purpose is A45?  purpose is A46?  purpose is A48?  purpose is A49?
# 656                0                0                0                0
# 187                0                0                0                0
# 770                0                0                0                0
# 288                0                0                0                0
# 106                0                0                0                0

# %%
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (640, 45) (160, 45) (200, 45)

# %% [markdown]
# # Itteration 1

# %%
reg = LogisticRegression()
reg.fit(X_train, y_train.values.ravel())
predict = reg.predict(X_val)
acc = accuracy_score(y_val, predict)
print("Accuracy on Validation Set: " + str(acc))
predict = reg.predict(X_test)
acc = accuracy_score(y_test, predict)
print("Accuracy on Test Set: " + str(acc))
# Out:
# Accuracy on Validation Set: 0.74375
# Accuracy on Test Set: 0.725

# %% [markdown]
# ### Transformation

# %% [markdown]
# Applying transformation to treat outliers

# %%
sns.set_palette(sns.color_palette('coolwarm'))
right_skew_removal(X_train, 'duration')
right_skew_removal(X_test, 'duration')
right_skew_removal(X_val, 'duration')

plt.subplot('211')
sns.distplot(X_train['duration'])
plt.subplot('212')
sns.boxplot(X_train['duration'])
plt.show()

right_skew_removal(X_train, 'amount')
right_skew_removal(X_test, 'amount')
right_skew_removal(X_val, 'amount')

plt.subplot('211')
sns.distplot(X_train['amount'])
plt.subplot('212')
sns.boxplot(X_train['amount'])
plt.show()

right_skew_removal(X_train, 'age')
right_skew_removal(X_test, 'age')
right_skew_removal(X_val, 'age')

plt.subplot('211')
sns.distplot(X_train['age'])
plt.subplot('212')
sns.boxplot(X_train['age'])
plt.show()

# %% [markdown]
# ### Outliers Removal

# %% [markdown]
# Atlast remove all the outliers after transformation

# %%
for i in num_train_cols:
    remove_outlier(X_train, i)
# Out:
# duration
# amount
# age

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Logistic Regression

# %%
reg = LogisticRegression()
reg.fit(X_train, y_train.values.ravel())
predict = reg.predict(X_val)
acc = accuracy_score(y_val, predict)
print("Accuracy on Validation Set: " + str(acc))
predict = reg.predict(X_test)
acc = accuracy_score(y_test, predict)
print("Accuracy on Test Set: " + str(acc))
plot_features(X_train, X_val, y_train, y_val, reg)
# Out:
# Accuracy on Validation Set: 0.73125
# Accuracy on Test Set: 0.71

# %% [markdown]
# ## SVM

# %%
clf = svm.SVC()
clf.fit(X_train, y_train.values.ravel())
predict = clf.predict(X_val)
acc = accuracy_score(y_val, predict)
cnf_matrix = confusion_matrix(y_val, predict)
print("Accuracy on Validation Set: " + str(acc))
print("Confusion matrix for Validation Set")
print(cnf_matrix)
predict = clf.predict(X_test)
acc = accuracy_score(y_test, predict)
cnf_matrix = confusion_matrix(y_test, predict)
print("Accuracy on Test Set: " + str(acc))
print("Confusion matrix for Test Set")
print(cnf_matrix)

plot_features(X_train, X_val, y_train, y_val, reg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-32f563174122> in <module>()
#       1 clf = svm.SVC()
# ----> 2 clf.fit(X_train, y_train.values.ravel())
#       3 predict = clf.predict(X_val)
#       4 acc = accuracy_score(y_val, predict)
#       5 cnf_matrix = confusion_matrix(y_val, predict)
#
# ~/anaconda2/envs/credit/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# ~/anaconda2/envs/credit/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/anaconda2/envs/credit/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'A201'

# %% [markdown]
# # Decision Tree

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(X_train, y_train.values.ravel())
predict = clf.predict(X_val)
acc = accuracy_score(y_val, predict)
cnf_matrix = confusion_matrix(y_val, predict)
print("Accuracy on Validation Set: " + str(acc))
print("Confusion matrix for Validation Set")
print(cnf_matrix)
predict = clf.predict(X_test)
acc = accuracy_score(y_test, predict)
cnf_matrix = confusion_matrix(y_test, predict)
print("Accuracy on Test Set: " + str(acc))
print("Confusion matrix for Test Set")
print(cnf_matrix)

plot_features_clf(clf)
# Out:
# Accuracy on Validation Set: 0.7
# Confusion matrix for Validation Set
# [[90 18]
#  [30 22]]
# Accuracy on Test Set: 0.645
# Confusion matrix for Test Set
# [[106  33]
#  [ 38  23]]

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier(max_depth=3, random_state=0)
clf.fit(X_train, y_train.values.ravel())
predict = clf.predict(X_val)
acc = accuracy_score(y_val, predict)
cnf_matrix = confusion_matrix(y_val, predict)
print("Accuracy on Validation Set: " + str(acc))
print("Confusion matrix for Validation Set")
print(cnf_matrix)
predict = clf.predict(X_test)
acc = accuracy_score(y_test, predict)
cnf_matrix = confusion_matrix(y_test, predict)
print("Accuracy on Test Set: " + str(acc))
print("Confusion matrix for Test Set")
print(cnf_matrix)

plot_features_clf(clf)
# Out:
# Accuracy on Validation Set: 0.68125
# Confusion matrix for Validation Set
# [[108   0]
#  [ 51   1]]
# Accuracy on Test Set: 0.7
# Confusion matrix for Test Set
# [[139   0]
#  [ 60   1]]

# %% [markdown]
# ## Gradient Boosting

# %%
clf = GradientBoostingClassifier(max_depth=3, random_state=0)
clf.fit(X_train, y_train.values.ravel())
predict = clf.predict(X_val)
acc = accuracy_score(y_val, predict)
cnf_matrix = confusion_matrix(y_val, predict)
print("Accuracy on Validation Set: " + str(acc))
print("Confusion matrix for Validation Set")
print(cnf_matrix)
predict = clf.predict(X_test)
acc = accuracy_score(y_test, predict)
cnf_matrix = confusion_matrix(y_test, predict)
print("Accuracy on Test Set: " + str(acc))
print("Confusion matrix for Test Set")
print(cnf_matrix)

plot_features_clf(clf)
# Out:
# Accuracy on Validation Set: 0.78125
# Confusion matrix for Validation Set
# [[100   8]
#  [ 27  25]]
# Accuracy on Test Set: 0.71
# Confusion matrix for Test Set
# [[117  22]
#  [ 36  25]]

# %% [markdown]
# ## Ada Boost

# %%
clf = AdaBoostClassifier()
clf.fit(X_train, y_train.values.ravel())
predict = clf.predict(X_val)
acc = accuracy_score(y_val, predict)
cnf_matrix = confusion_matrix(y_val, predict)
print("Accuracy on Validation Set: " + str(acc))
print("Confusion matrix for Validation Set")
print(cnf_matrix)
predict = clf.predict(X_test)
acc = accuracy_score(y_test, predict)
cnf_matrix = confusion_matrix(y_test, predict)
print("Accuracy on Test Set: " + str(acc))
print("Confusion matrix for Test Set")
print(cnf_matrix)
plot_features_clf(clf)
# Out:
# Accuracy on Validation Set: 0.75
# Confusion matrix for Validation Set
# [[99  9]
#  [31 21]]
# Accuracy on Test Set: 0.73
# Confusion matrix for Test Set
# [[121  18]
#  [ 36  25]]

# %%
def plot_cm(cm):
    plt.clf()
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
    classNames = ['Negative','Positive']
    plt.title('Good/Bad Loan Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    tick_marks = np.arange(len(classNames))
    plt.xticks(tick_marks, classNames, rotation=45)
    plt.yticks(tick_marks, classNames)
    s = [['TN','FP'], ['FN', 'TP']]
    for i in range(2):
        for j in range(2):
            plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
    plt.show()
